# %%
import pandas as pd

# %% [markdown]
# # Agenda

# %% [markdown]
# 1. Data Structure
# 2. Input/output
# 3. Data Exploration
# 4. Data Manuplation
# 5. Visualization

# %%
#data Structure..

#Series..

data = [10,20,30,40,50,60]
series = pd.Series(data)

# %%
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
#DataFrame..

data1 = {'Name': ['a','b','c','d'],
         'Age': [15,16,17,18],
        'city': ['Banglore','pune','Mumbai', 'Chennai']}

# %%
df = pd.DataFrame(data1)

# %%
df
# Out:
#   Name  Age      city
# 0    a   15  Banglore
# 1    b   16      pune
# 2    c   17    Mumbai
# 3    d   18   Chennai

# %%
#Input/output...

#1. Reading Data..

df1 = pd.read_csv('IRIS.csv')
df5 = df1

# %%
#2. Write Data..

df.to_csv('outputfile.csv')

# %%
pd.read_csv('outputfile.csv')
# Out:
#    Unnamed: 0 Name  Age      city
# 0           0    a   15  Banglore
# 1           1    b   16      pune
# 2           2    c   17    Mumbai
# 3           3    d   18   Chennai

# %%
#Data Exploration

#basic imformation..

df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df1.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df1.shape
# Out:
# (150, 5)

# %%
#2. Descriptive Statistics..

df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.median()
# Out:
# C:\Users\123sa\AppData\Local\Temp\ipykernel_23208\2279417019.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.median()
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
df1.corr()
# Out:
# C:\Users\123sa\AppData\Local\Temp\ipykernel_23208\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
#3. Sorting and Filtering data.

#Sorting..

# sorting data frame syntax
df2 = df1.sort_values("petal_length", axis = 0, ascending = True,
                  na_position ='last')

df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 32            5.2          4.1           1.5          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#filtering..

vers = df1[df1['species'] == "Iris-virginica" ]

# %%
vers.shape
# Out:
# (50, 5)

# %%
df6 = df1[df1['sepal_length'] >= 5.8  ]

# %%
#Data Manuplation

df1['sepal_width'].values
# Out:
# array([6.1, 5.9, 5.7, 5.6, 6. , 6.4, 5.6, 6. , 5.4, 5.9, 6.4, 5.8, 5.8,
#        5.3, 6.8, 6.7, 6.4, 6.1, 6.7, 6.1, 6.4, 6.1, 5.6, 6.1, 5.8, 6. ,
#        6. , 6.2, 6.2, 5.7, 5.8, 6.4, 6.2, 6.5, 5.9, 6. , 6.5, 5.9, 5.4,
#        6.1, 6. , 5.5, 5.4, 6. , 6.1, 5.8, 6.1, 5.6, 6.3, 6. , 8. , 7.4,
#        7.9, 6.5, 7.5, 6.7, 7.3, 5.9, 7.6, 6.2, 6. , 6.9, 7. , 7.1, 6.6,
#        7.7, 6.6, 6.8, 7.2, 6.6, 6.9, 7.1, 7.3, 7.1, 7.4, 7.6, 7.8, 7.7,
#        7. , 6.7, 6.5, 6.5, 6.8, 7. , 6.4, 7. , 7.7, 7.3, 6.6, 6.5, 6.5,
#        7.1, 6.8, 6. , 6.6, 6.7, 6.7, 7.2, 6.1, 6.7, 7.3, 6.8, 8.1, 7.3,
#        7.5, 8.6, 5.9, 8.3, 7.7, 8.2, 7.5, 7.4, 7.8, 6.7, 6.8, 7.4, 7.5,
#        8.7, 8.7, 7. , 7.9, 6.6, 8.7, 7.3, 7.7, 8.2, 7.2, 7.1, 7.4, 8.2,
#        8.4, 8.9, 7.4, 7.3, 7.1, 8.7, 7.3, 7.4, 7. , 7.9, 7.7, 7.9, 6.8,
#        7.8, 7.7, 7.7, 7.3, 7.5, 7.2, 6.9])

# %%
#handling Missing Values..

df1.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df1.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          6.1           1.4          0.2     Iris-setosa
# 1             4.9          5.9           1.4          0.2     Iris-setosa
# 2             4.7          5.7           1.3          0.2     Iris-setosa
# 3             4.6          5.6           1.5          0.2     Iris-setosa
# 4             5.0          6.0           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          7.7           5.2          2.3  Iris-virginica
# 146           6.3          7.3           5.0          1.9  Iris-virginica
# 147           6.5          7.5           5.2          2.0  Iris-virginica
# 148           6.2          7.2           5.4          2.3  Iris-virginica
# 149           5.9          6.9           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#df1.fillna()

# %%
#groupby & Aggregation.


df1.groupby('sepal_length').sum()
# Out:
# C:\Users\123sa\AppData\Local\Temp\ipykernel_23208\3090641211.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1.groupby('sepal_length').sum()
#               sepal_width  petal_length  petal_width
# sepal_length
# 4.3                   5.3           1.1          0.1
# 4.4                  16.2           4.0          0.6
# 4.5                   5.5           1.3          0.3
# 4.6                  22.4           5.3          0.9
# 4.7                  11.4           2.9          0.4
# 4.8                  29.0           7.9          1.0
# 4.9                  35.4          13.7          3.2
# 5.0                  60.0          18.4          4.3
# 5.1                  54.9          15.5          3.6
# 5.2                  24.8           8.3          1.9
# ...

# %%
#merging data..

df6.to_csv('out1.csv')

# %%
pd.concat([df1, df6])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          6.1           1.4          0.2     Iris-setosa
# 1             4.9          5.9           1.4          0.2     Iris-setosa
# 2             4.7          5.7           1.3          0.2     Iris-setosa
# 3             4.6          5.6           1.5          0.2     Iris-setosa
# 4             5.0          6.0           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          7.7           5.2          2.3  Iris-virginica
# 146           6.3          7.3           5.0          1.9  Iris-virginica
# 147           6.5          7.5           5.2          2.0  Iris-virginica
# 148           6.2          7.2           5.4          2.3  Iris-virginica
# 149           5.9          6.9           5.1          1.8  Iris-virginica
#
# [227 rows x 5 columns]

# %%
pd.merge(df1, df6, on= 'species')
# Out:
#       sepal_length_x  sepal_width_x  petal_length_x  petal_width_x  \
# 0                5.1            6.1             1.4            0.2
# 1                4.9            5.9             1.4            0.2
# 2                4.7            5.7             1.3            0.2
# 3                4.6            5.6             1.5            0.2
# 4                5.0            6.0             1.4            0.2
# ...              ...            ...             ...            ...
# 3845             5.9            6.9             5.1            1.8
# 3846             5.9            6.9             5.1            1.8
# 3847             5.9            6.9             5.1            1.8
# 3848             5.9            6.9             5.1            1.8
# 3849             5.9            6.9             5.1            1.8
#
#              species  sepal_length_y  sepal_width_y  petal_length_y  \
# 0        Iris-setosa             5.8            6.8             1.2
# ...

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Visualization..
import matplotlib.pyplot as plt

plt.scatter(df2['sepal_length'], df2['sepal_width'])
